# %%
import numpy as np
np.random.seed(1337)
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline


from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from collections import deque
import random
import urllib, json
import re
from datetime import datetime
import requests
# Out:
# Using TensorFlow backend.

# %%
memory = deque(maxlen=2000)
gamma = 0.95  
epsilon = 0.05  # exploration rate
epsilon_min = 0.01
epsilon_decay = 0.99
learning_rate = 0.001
batch_size = 5
memory = []
action_hist = []
class Account:
    cash = 100000
    amount_held = 0
    def calc_value(self,current_price):
        return self.amount_held * current_price
account = Account()

# %%
def build_network(input_sz):
    model = Sequential()
    model.add(Dense(125,input_dim=input_sz, activation='relu'))
    model.add(Dense(50,activation='relu'))
    model.add(Dense(2, activation='linear'))
    try:
        model.load_weights("rltrader.h5")
        print "LOADEd weights"
    except:
        pass
    model.compile(loss='mse',optimizer=Adam(lr=learning_rate)) 
    return model

# %%
def get_data(symbol):
    q = deque(maxlen=3)
    url = "https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&outputsize=full&symbol="+symbol+"&apikey=TOGGSCK5JLEEJTGL"
    url_rsi = "https://www.alphavantage.co/query?function=RSI&symbol="+symbol+"&interval=daily&time_period=10&series_type=close&apikey=TOGGSCK5JLEEJTGL"
    url_sma = "https://www.alphavantage.co/query?function=SMA&symbol="+symbol+"&interval=daily&time_period=10&series_type=close&apikey=TOGGSCK5JLEEJTGL"
    url_cci = "https://www.alphavantage.co/query?function=CCI&symbol="+symbol+"&interval=daily&time_period=10&series_type=close&apikey=TOGGSCK5JLEEJTGL"
    
    response_prices = requests.get(url)
    response_rsi = requests.get(url_rsi)
    response_sma = requests.get(url_sma)
    response_cci = requests.get(url_cci)
    
    data = response_prices.json()
    data_rsi = response_rsi.json()
    data_sma = response_sma.json()
    data_cci = response_cci.json()
    
    
    data = data["Time Series (Daily)"]
#     print(data_rsi)
    data_rsi = data_rsi["Technical Analysis: RSI"]
    data_sma = data_sma["Technical Analysis: SMA"]
    data_cci = data_cci["Technical Analysis: CCI"]
    
    ds = {}
    ds["date"] = []
    ds["close"] = []
    ds["trend"] = []
#     ds["open"] = []
#     ds["volume"] = []
#     ds["high"] = []
#     ds["low"] = []
    ds["rsi"] = []
    ds["sma"] = []
    ds["cci"] = []
    
#     i = 0
    q.append(1)
    for time_point in data:
        try:
            ds["date"] += [time_point]
            ds["close"] += [float(data[time_point]["4. close"])]
            ds["trend"] += [(float(data[time_point]["4. close"])-(sum(list(q))/len(list(q))))/(sum(list(q))/len(list(q)))]
            last_close = float(data[time_point]["4. close"])
            if last_close <= 0:
                q.append(1)
            else:
                q.append(last_close)
#             ds["open"] += [float(data[time_point]["1. open"])]
#             ds["volume"] += [float(data[time_point]["5. volume"])]
#             ds["high"] += [float(data[time_point]["2. high"])]
#             ds["low"] += [float(data[time_point][ "3. low"])]
        except KeyError as e:
            continue
        try:
            ds["rsi"] += [float(data_rsi[time_point]["RSI"])]
        except KeyError as e:
            ds["rsi"] += [sum(ds["rsi"])/len(ds["rsi"])]
        try:
            ds["sma"] += [float(data_sma[time_point]["SMA"])]
        except KeyError as e:
            ds["sma"] += [sum(ds["sma"])/len(ds["sma"])]
        try:
            ds["cci"] += [float(data_cci[time_point]["CCI"])]
        except KeyError as e:
            ds["cci"] += [sum(ds["cci"])/len(ds["cci"])]
    
    df=pd.DataFrame(ds)
    df = df.sort_values(by='date')
    df = df.reset_index(drop=True)
    return df

# %%
def remember(s,a,r,sp):
    memory.append((s,a,r,sp))

# %%
def update(memory):
#     Take random sample from memory
    batch = random.sample(memory, batch_size) 
#     Train network on batch
    for s, a, r, sp in batch:
#       if state is final there is no future rewards
        target = r
#       discounted future rewards
    
        target = r + gamma * \
           np.amax(model.predict(sp)[0])
                
#       Get pred then replace action with our target
        target_f = model.predict(s)
        target_f[0][a] = target
        model.fit(s, target_f, epochs=1, verbose=0)

# %%
def get_act(obs):
#     epsilon = epsilon*epsilon_decay
    if np.random.rand() <= epsilon:
        # The agent acts randomly
#         epsilon = epsilon*epsilon_decay
        act = int(random.uniform(0, 2))
        return act
  
    # Predict the reward value based on the given state
    act_values = model.predict(obs)

    # Pick the action based on the predicted reward
    return np.argmax(act_values[0])

# %%
int(random.uniform(0, 2))
# Out:
# 1

# %%
def act(act,day):
    current_val = account.calc_value(day[1]["close"])
    i = day[0]
    future = df.close.iloc[i:i+3].mean()
    if act == 1:
        buy["buy"] += [day[1]["close"]]
        buy["date"] += [df_d.date.iloc[day[0]]]
        if (account.cash - (day[1]["close"]*20)) >= 0:
            account.amount_held =  account.amount_held + 20
            account.cash = account.cash - (20*day[1]["close"])
        if ((future - day[1]["close"])/day[1]["close"]) > 0:
            return 1
        else:
            return -1
#             if (account.calc_value(future) - current_val) > 0:
#                 return 1
#             else:
#                 return -1
    #         Buy some shares reward is if we make money in a week
    else:
        
        sell["sell"] += [day[1]["close"]]
        sell["date"] += [df_d.date.iloc[day[0]]]
        to_sell =int((random.random()*account.amount_held))
        if account.amount_held > 0:
            account.cash = account.cash + (to_sell*day[1]["close"])
            account.amount_held = account.amount_held -to_sell
        if -((future - day[1]["close"])/day[1]["close"]) > 0:
            return 1
        else:
            return -1
#         if (account.calc_value(future) - current_val) < 0:
#             return 1
#         else:
#             return -1
    
    return -0.05
#         Sell some shares reward is if we avoid losing money in a week

# %%
#     print d[1]["date"]

# %%
range(0,1)
# Out:
# [0]

# %%
# model = build_network(len(df.columns))
# prv_obs = None
feats = ["trend","rsi","sma","cci"]
buy = {}
buy["buy"] = []
buy["date"] = []
sell = {}
sell["sell"] = []
sell["date"] = []
worth = {}
worth["worth"]=[]
gl = []
epochs = 1
df_d = None
codes = ["ASX:RBL","TSLA","MSFT","MU","ASX:ANZ","NVDA"]
for epoch in range(0,epochs):
    buy = {}
    buy["buy"] = []
    buy["date"] = []
    sell = {}
    sell["sell"] = []
    sell["date"] = []
    worth = {}
    worth["worth"]=[]
    gl = []
    i = 0
    memory = deque(maxlen=2000)
    account = Account()
    df = get_data("NVDA")
    df_d = df[["date","close"]]
    del df["date"]
    model = build_network(len(df[feats].columns))
    prv_obs = None

    for day in df.iterrows():
        i = 1 + i
    #     print i
        if i == len(df) - 11:
            model.save_weights("rltrader.h5")
            print("Episode finished after {} timesteps".format(i+1))
            break
        obs = day[1]
        obs_values = np.reshape(obs[feats].values,[1,len(df[feats].columns)])
        action = get_act(obs_values )
        if action == 1:
            action_hist += ["buy"] 
        else:
            action_hist += ["sell"]
        if i % 100 == 0:
            if action == 1:
                print "Buying" 
            else:
                print "Selling"
            print "day" , i
            print "cash",account.cash
            print "shares held",account.amount_held
            print "net worth",account.calc_value(day[1]["close"]) + account.cash
        worth["worth"] += [account.calc_value(day[1]["close"]) + account.cash]
    #     print(action)
        reward = act(action,day)
    #     print reward
        gl += [(account.calc_value(day[1]["close"]) + account.cash) - 100000]
#         if prv_obs is not None and reward is not None:
#             remember(prv_obs,action,reward,obs_values)
        prv_obs = obs_values  
    #     if done:
    #         model.save_weights("model.h5")
    #         print("Episode finished after {} timesteps".format(t+1))
    #         break
        if len(memory) >= batch_size:
            update(memory)
    print ((sum(gl)/len(gl))/100000)*100
# Out:
# LOADEd weights
# Buying
# day 100
# cash 127449.38
# shares held 49
# net worth 132667.88
# Buying
# day 200
# cash 105676.16
# shares held 514
# net worth 138381.98
# Buying
# day 300
# cash 59904.25
# shares held 1251
# net worth 120265.0
# Selling
# day 400
# cash 188454.18
# shares held 56
# net worth 193375.46
# Buying
# day 500
# cash 107817.98
# shares held 1548
# net worth 211379.18
# Buying
# day 600
# cash 54891.75
# shares held 2623
# net worth 146775.44
# Buying
# day 700
# cash 24696.242
# shares held 4425
# net worth 62972.492
# Buying
# day 800
# cash 10707.862
# shares held 5426
# net worth 78912.682
# Buying
# day 900
# cash 72255.832
# shares held 1598
# net worth 104950.912
# Buying
# day 1000
# cash 75810.522
# shares held 1472
# net worth 107900.122
# Buying
# day 1100
# cash 104559.762
# shares held 385
# net worth 112821.862
# Buying
# day 1200
# cash 89133.268
# shares held 1297
# net worth 107706.308
# Buying
# day 1300
# cash 65294.448
# shares held 2483
# net worth 134445.998
# Buying
# day 1400
# cash 104628.658
# shares held 938
# net worth 130207.918
# Buying
# day 1500
# cash 114615.888
# shares held 599
# net worth 136323.648
# Buying
# day 1600
# cash 71391.316
# shares held 1399
# net worth 108758.606
# Buying
# day 1700
# cash 91585.086
# shares held 864
# net worth 117677.886
# Buying
# day 1800
# cash 110104.456
# shares held 354
# net worth 120643.036
# Buying
# day 1900
# cash 91694.276
# shares held 822
# net worth 127977.356
# Buying
# day 2000
# cash 118274.7855
# shares held 349
# net worth 130514.2155
# Buying
# day 2100
# cash 93195.6965
# shares held 1464
# net worth 126179.6165
# Buying
# day 2200
# cash 103372.6865
# shares held 1603
# net worth 120059.9165
# Buying
# day 2300
# cash 87540.8465
# shares held 3603
# net worth 116364.8465
# Buying
# day 2400
# cash 122163.1665
# shares held 516
# net worth 128468.6865
# Buying
# day 2500
# cash 102200.0865
# shares held 1938
# net worth 132607.3065
# Buying
# day 2600
# cash 115415.7465
# shares held 1144
# net worth 132003.7465
# Selling
# day 2700
# cash 99450.3085
# shares held 2726
# net worth 132148.6785
# Buying
# day 2800
# cash 105868.9385
# shares held 1517
# net worth 144825.4985
# Buying
# day 2900
# cash 69087.0985
# shares held 3517
# net worth 120646.3185
# Buying
# day 3000
# cash 109430.7985
# shares held 421
# net worth 116048.9185
# Buying
# day 3100
# cash 81482.6485
# shares held 2332
# net worth 111752.0085
# Buying
# day 3200
# cash 90908.0385
# shares held 1539
# net worth 112007.7285
# Buying
# day 3300
# cash 72060.7365
# shares held 3062
# net worth 111039.9965
# Buying
# day 3400
# cash 108591.7105
# shares held 218
# net worth 111737.4505
# Buying
# day 3500
# cash 84310.9205
# shares held 1811
# net worth 112562.5205
# Buying
# day 3600
# cash 90105.4505
# shares held 1646
# net worth 120935.0305
# Buying
# day 3700
# cash 117443.1405
# shares held 186
# net worth 121005.0405
# Buying
# day 3800
# cash 115453.6805
# shares held 334
# net worth 122450.9805
# Buying
# day 3900
# cash 113686.5905
# shares held 459
# net worth 122944.6205
# Buying
# day 4000
# cash 103790.8405
# shares held 846
# net worth 130160.6605
# Buying
# day 4100
# cash 97860.5905
# shares held 721
# net worth 124141.0405
# Buying
# day 4200
# cash 40217.7405
# shares held 1770
# net worth 147745.2405
# Selling
# day 4300
# cash 179298.2305
# shares held 29
# net worth 182615.2505
# Buying
# day 4400
# cash 131662.1205
# shares held 370
# net worth 187809.6205
# Episode finished after 4444 timesteps
# 27.1351634688

# %%
print ((sum(gl)/len(gl))/100000)*100
# df_d
print (133605.115/100000)*100
# print action_hist
# Out:
# 27.1351634688
# 133.605115

# %%
df_buys = pd.DataFrame(buy)
df_sells = pd.DataFrame(sell)
df_worth = pd.DataFrame(worth)

# %%
df_d.plot()
df_worth.plot()

# %%
df_buys.plot(style=".")

# %%
# df_d.plot()
df_sells.plot(style=".")

# %%
df_d.date = pd.to_datetime(df_d.date,format='%Y-%m-%d')
df_d = df_d.set_index("date")
df_buys.date = pd.to_datetime(df_buys.date,format='%Y-%m-%d')
df_buys = df_buys.set_index("date")
df_sells.date = pd.to_datetime(df_sells.date,format='%Y-%m-%d')
df_sells = df_sells.set_index("date")
ax = df_d.plot()

ax = df_d.plot()
ax = df_buys.plot(ax=ax)
df_sells.plot(ax=ax)
# # df_sells.groupby(df_sells["date"])
plt.show()

# %%
fig = plt.figure(figsize = (50,50))
ax = fig.gca()
df.rsi.plot(ax=ax)

# %%
fig = plt.figure(figsize = (50,50))
ax = fig.gca()
ax = df_d.plot(ax=ax)
ax = df_buys.plot(style=".",ax=ax)
df_sells.plot(style=".",ax=ax)
# # df_sells.groupby(df_sells["date"])
plt.show()

# %%
df_d
# Out:
#             close
# date
# 2016-05-16  1.455
# 2016-05-17  1.430
# 2016-05-18  1.400
# 2016-05-19  1.400
# 2016-05-20  1.360
# 2016-05-23  1.360
# 2016-05-24  1.280
# 2016-05-25  1.310
# 2016-05-26  1.280
# 2016-05-27  1.205
# 2016-05-30  1.120
# 2016-05-31  1.220
# 2016-06-01  1.180
# 2016-06-02  1.210
# 2016-06-03  1.230
# 2016-06-06  1.210
# 2016-06-07  1.185
# 2016-06-08  1.160
# 2016-06-09  1.150
# 2016-06-10  1.155
# 2016-06-14  1.180
# 2016-06-15  1.090
# 2016-06-16  1.120
# 2016-06-17  1.120
# 2016-06-20  1.080
# 2016-06-21  1.180
# 2016-06-22  1.150
# 2016-06-23  1.110
# 2016-06-24  1.050
# 2016-06-27  1.045
# ...           ...
# 2017-08-04  0.840
# 2017-08-07  0.800
# 2017-08-08  0.800
# 2017-08-09  0.800
# 2017-08-10  0.800
# 2017-08-11  0.800
# 2017-08-14  0.790
# 2017-08-15  0.780
# 2017-08-16  0.775
# 2017-08-17  0.790
# 2017-08-18  0.795
# 2017-08-21  0.790
# 2017-08-22  0.780
# 2017-08-23  0.780
# 2017-08-24  0.800
# 2017-08-25  0.800
# 2017-08-28  0.780
# 2017-08-29  0.780
# 2017-08-30  0.780
# 2017-08-31  0.780
# 2017-09-01  0.775
# 2017-09-04  0.725
# 2017-09-05  0.705
# 2017-09-06  0.730
# 2017-09-07  0.730
# 2017-09-08  0.730
# 2017-09-11  0.715
# 2017-09-12  0.705
# 2017-09-13  0.750
# 2017-09-14  0.705
#
# [340 rows x 1 columns]

# %%
# %%bash
# which python
# Out:
# /home/wolf/anaconda2/bin/python
