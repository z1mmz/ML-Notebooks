# %%
import gym
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from collections import deque
import numpy as np
import random
# Out:
# Using TensorFlow backend.

# %%
# with help from https://keon.io/deep-q-learning/
# Adopted from my attempts at DQN with pacman
memory = deque(maxlen=2000)
gamma = 0.95  
epsilon = 0.09  # exploration rate
epsilon_min = 0.01
epsilon_decay = 0.9
learning_rate = 0.005
batch_size = 32
obs_dim = 3
memory = []

def build_network():
    model = Sequential()
    model.add(Dense(125,input_dim=obs_dim, activation='relu',name="input"))
    model.add(Dense(50,activation='relu',name="fc1"))
    model.add(Dense(50,activation='relu',name="fc2"))
    model.add(Dense(2 ,activation='linear',name="out"))
    try:
        model.load_weights("model_pend.h5")
        print "LOADEd weights"
    except:
        pass
    model.compile(loss='mse',optimizer=Adam(lr=learning_rate)) 
    return model
model = build_network()
def remember(s,a,r,sp,d):
    memory.append((s,a,r,sp,d))
def update(memory):
#     Take random sample from memory
    batch = random.sample(memory, batch_size) 
#     Train network on batch
    for s, a, r, sp, d in batch:
#       if state is final there is no future rewards
        target = r
#       discounted future rewards
        if not d:
            target = r + gamma * \
               np.amax(model.predict(sp)[0])
                
#       Get pred then replace action with our target
        target_f = model.predict(s)
#         print(a)
        target_f[0][a] = target
        print(target_f)
#         print(target,s)
        model.fit(s,target_f, epochs=1, verbose=0)
def act(obs):
    if np.random.rand() <= epsilon:
        # The agent acts randomly
        return env.action_space.sample()
  
    # Predict the reward value based on the given state
    act_values = model.predict(obs)
    print act_values

    # Pick the action based on the predicted reward
    return np.argmax(act_values[0])
# Out:
# LOADEd weights

# %%
import gym
env = gym.make('Pendulum-v0')
for i_episode in range(1000):
#     print env.action_space.sample()
    obs = env.reset() # reset for each new trial
    obs = np.reshape(obs,[1,obs_dim])
#     print(observation)
    for t in range(1000): # run for 100 timesteps or until done, whichever is first
        if i_episode > 50:
            env.render()
        
        action = act(obs)
        print(action ,'ACTION')
        prv_obs = obs
     
        obs, reward, done, info = env.step([action])
#         print type(reward)
        if type(reward) is not np.array:
            reward = np.array([reward])
        obs = np.reshape(obs,[1,obs_dim])
#         print action
        remember(prv_obs,action,reward,obs,done)
        
        if done:
            model.save_weights("model_pend.h5")
            print("Episode finished after {} timesteps".format(t+1))
            break
    if len(memory) >= batch_size:
        update(memory)
# Out:
# [2017-08-23 17:32:05,345] Making new env: Pendulum-v0
# [[-6.89266729 -7.26811886]]
# (0, 'ACTION')
# (array([ 0.19525402]), 'ACTION')
# [[-6.54380274 -6.80342913]]
# (0, 'ACTION')
# [[-6.42264843 -6.59587193]]
# (0, 'ACTION')
# [[-6.40305424 -6.47498655]]
# (0, 'ACTION')
# [[-6.56423378 -6.5208025 ]]
# (1, 'ACTION')
# [[-6.67358541 -6.61210775]]
# (1, 'ACTION')
# [[-6.86971235 -6.77294207]]
# (1, 'ACTION')
# [[-7.15808678 -7.00958538]]
# (1, 'ACTION')
# [[-7.63088751 -7.42079115]]
# (1, 'ACTION')
# [[-8.3533659  -8.06881714]]
# (1, 'ACTION')
# (array([ 0.86075747]), 'ACTION')
# [[-10.78766537 -10.29768658]]
# (1, 'ACTION')
# [[-12.41863918 -11.79398823]]
# (1, 'ACTION')
# [[-14.40024853 -13.60988331]]
# (1, 'ACTION')
# [[-16.82522964 -15.84362507]]
# (1, 'ACTION')
# [[-19.69184685 -18.48195076]]
# (1, 'ACTION')
# [[-22.98525047 -21.51200104]]
# (1, 'ACTION')
# (array([ 0.4110535]), 'ACTION')
# [[-30.89884758 -28.75214195]]
# (1, 'ACTION')
# [[-34.55848694 -32.06445694]]
# (1, 'ACTION')
# [[-37.65666199 -34.83169174]]
# (1, 'ACTION')
# [[-39.83876801 -36.78356171]]
# (1, 'ACTION')
# [[-40.6885643  -37.52324677]]
# (1, 'ACTION')
# [[-39.9954071  -36.85821152]]
# (1, 'ACTION')
# [[-37.80839539 -34.826828  ]]
# (1, 'ACTION')
# [[-34.48823166 -31.76316071]]
# (1, 'ACTION')
# [[-30.31255341 -27.91952133]]
# (1, 'ACTION')
# [[-25.67066002 -23.6538353 ]]
# (1, 'ACTION')
# [[-20.86519051 -19.24494362]]
# (1, 'ACTION')
# [[-16.12436485 -14.89207649]]
# (1, 'ACTION')
# [[-12.20297909 -11.38347816]]
# (1, 'ACTION')
# [[-10.35022736 -10.18320274]]
# (1, 'ACTION')
# [[-13.09314442 -13.80099773]]
# (0, 'ACTION')
# [[-17.70219421 -19.01605415]]
# (0, 'ACTION')
# [[-23.57924843 -25.47428131]]
# (0, 'ACTION')
# [[-29.86482811 -32.34408951]]
# (0, 'ACTION')
# [[-36.30205536 -39.37410736]]
# (0, 'ACTION')
# [[-42.49297333 -46.1402626 ]]
# (0, 'ACTION')
# [[-48.09651947 -52.2674408 ]]
# (0, 'ACTION')
# [[-52.60823822 -57.20519638]]
# (0, 'ACTION')
# [[-55.54330826 -60.42964935]]
# (0, 'ACTION')
# [[-56.56183243 -61.56243134]]
# (0, 'ACTION')
# (array([ 0.17953273]), 'ACTION')
# [[-52.87228394 -57.56126785]]
# (0, 'ACTION')
# [[-48.4352951  -52.72800064]]
# (0, 'ACTION')
# [[-42.96949387 -46.77327728]]
# (0, 'ACTION')
# [[-36.91371155 -40.17362595]]
# (0, 'ACTION')
# [[-30.62613487 -33.31652451]]
# (0, 'ACTION')
# [[-24.40379715 -26.52142906]]
# (0, 'ACTION')
# [[-18.42218018 -19.97963905]]
# (0, 'ACTION')
# [[-13.40644169 -14.40652084]]
# (0, 'ACTION')
# [[-10.3784647  -10.88919449]]
# (0, 'ACTION')
# [[-10.16753578 -10.18115616]]
# (0, 'ACTION')
# (array([-0.3053808]), 'ACTION')
# [[-16.67888069 -15.83161926]]
# (1, 'ACTION')
# [[-19.88731194 -18.71944809]]
# (1, 'ACTION')
# [[-23.15122223 -21.66342926]]
# (1, 'ACTION')
# [[-26.33596802 -24.54208565]]
# (1, 'ACTION')
# [[-29.11581993 -27.03775406]]
# (1, 'ACTION')
# [[-31.19532585 -28.8795929 ]]
# (1, 'ACTION')
# [[-32.38983154 -29.92556953]]
# (1, 'ACTION')
# [[-32.61058044 -30.10740471]]
# (1, 'ACTION')
# [[-31.72470284 -29.27918243]]
# (1, 'ACTION')
# (array([ 0.58357645]), 'ACTION')
# [[-27.28512001 -25.18190765]]
# (1, 'ACTION')
# [[-23.85822678 -22.033144  ]]
# (1, 'ACTION')
# [[-20.10464859 -18.59411621]]
# (1, 'ACTION')
# [[-16.54747963 -15.37506008]]
# (1, 'ACTION')
# [[-13.70427608 -13.00974464]]
# (1, 'ACTION')
# [[-12.8721962 -12.9335022]]
# (0, 'ACTION')
# [[-15.13519764 -15.99156952]]
# (0, 'ACTION')
# [[-19.38023186 -20.78850365]]
# (0, 'ACTION')
# [[-24.38645744 -26.32046509]]
# (0, 'ACTION')
# [[-29.53403282 -31.96473312]]
# (0, 'ACTION')
# [[-34.40974808 -37.30278397]]
# (0, 'ACTION')
# [[-38.64431    -41.93926239]]
# (0, 'ACTION')
# [[-41.96696472 -45.57937241]]
# (0, 'ACTION')
# [[-44.06087875 -47.88077545]]
# (0, 'ACTION')
# [[-44.79858398 -48.7015686 ]]
# (0, 'ACTION')
# [[-44.08946609 -47.9426918 ]]
# (0, 'ACTION')
# [[-42.05515671 -45.72947693]]
# (0, 'ACTION')
# [[-38.83476639 -42.21963501]]
# (0, 'ACTION')
# [[-34.70059204 -37.70875931]]
# (0, 'ACTION')
# [[-29.94135094 -32.51504135]]
# (0, 'ACTION')
# [[-24.8229866  -26.92254257]]
# (0, 'ACTION')
# [[-19.88061333 -21.46358681]]
# (0, 'ACTION')
# [[-15.72363663 -16.77445221]]
# (0, 'ACTION')
# [[-12.87476826 -13.44084644]]
# (0, 'ACTION')
# (array([-0.24965115]), 'ACTION')
# [[-14.19967175 -13.75396633]]
# (1, 'ACTION')
# [[-16.50462341 -15.73919773]]
# (1, 'ACTION')
# (array([ 1.567092]), 'ACTION')
# (array([ 1.85465104]), 'ACTION')
# [[-21.80574989 -20.35751915]]
# (1, 'ACTION')
# [[-23.21213722 -21.58919334]]
# (1, 'ACTION')
# [[-24.05165291 -22.31409264]]
# (1, 'ACTION')
# (array([-0.46623392]), 'ACTION')
# [[-24.91494179 -23.06167221]]
# (1, 'ACTION')
# [[-23.77092934 -22.00734138]]
# (1, 'ACTION')
# [[-22.09264755 -20.47747993]]
# (1, 'ACTION')
# [[-19.98691559 -18.56367111]]
# (1, 'ACTION')
# [[-17.78332901 -16.62112236]]
# (1, 'ACTION')
# [[-15.86812019 -15.07984638]]
# (1, 'ACTION')
# [[-14.64583683 -14.37524128]]
# (1, 'ACTION')
# [[-15.25126266 -15.6877737 ]]
# (0, 'ACTION')
# [[-17.16819    -18.16520119]]
# (0, 'ACTION')
# [[-19.9451828  -21.34480286]]
# (0, 'ACTION')
# [[-23.15523911 -24.93164825]]
# (0, 'ACTION')
# [[-26.29837227 -28.39679909]]
# (0, 'ACTION')
# [[-29.02243423 -31.39909363]]
# (0, 'ACTION')
# (array([ 1.16690015]), 'ACTION')
# [[-34.02884674 -36.89993668]]
# (0, 'ACTION')
# [[-34.59611511 -37.53104401]]
# (0, 'ACTION')
# [[-34.21084213 -37.12167358]]
# (0, 'ACTION')
# [[-32.9024353  -35.70279312]]
# (0, 'ACTION')
# [[-30.77635193 -33.38764954]]
# (0, 'ACTION')
# [[-28.00016403 -30.35285187]]
# (0, 'ACTION')
# [[-24.7879734  -26.82226372]]
# (0, 'ACTION')
# [[-21.55077553 -23.20140648]]
# (0, 'ACTION')
# (array([ 0.11557968]), 'ACTION')
# [[-15.76392555 -16.63433838]]
# (0, 'ACTION')
# (array([ 0.27217824]), 'ACTION')
# [[-13.91165638 -13.99091148]]
# (0, 'ACTION')
# [[-15.14109325 -14.81483173]]
# (1, 'ACTION')
# [[-16.25010109 -15.6662178 ]]
# (1, 'ACTION')
# [[-17.38634872 -16.58780289]]
# (1, 'ACTION')
# [[-18.361866   -17.38765335]]
# (1, 'ACTION')
# [[-19.10104752 -17.9951458 ]]
# (1, 'ACTION')
# [[-19.53212547 -18.34206581]]
# (1, 'ACTION')
# [[-19.60693741 -18.38481522]]
# (1, 'ACTION')
# [[-19.36592674 -18.17168236]]
# (1, 'ACTION')
# (array([ 1.70238655]), 'ACTION')
# [[-17.75849915 -16.87343216]]
# (1, 'ACTION')
# [[-16.87235451 -16.19077873]]
# (1, 'ACTION')
# [[-16.08697319 -15.67993546]]
# (1, 'ACTION')
# [[-15.65763474 -15.59579182]]
# (1, 'ACTION')
# [[-15.86672688 -16.21468544]]
# (0, 'ACTION')
# [[-16.55465889 -17.23635292]]
# (0, 'ACTION')
# [[-17.6301384  -18.56237793]]
# (0, 'ACTION')
# [[-18.81881142 -19.97132874]]
# (0, 'ACTION')
# [[-20.08015823 -21.42319489]]
# (0, 'ACTION')
# [[-21.23666    -22.74033737]]
# (0, 'ACTION')
# [[-22.18577576 -23.81210327]]
# (0, 'ACTION')
# [[-22.87703323 -24.58776474]]
# (0, 'ACTION')
# [[-23.24142456 -24.99596405]]
# (0, 'ACTION')
# [[-23.26923752 -25.02494431]]
# (0, 'ACTION')
# (array([-1.71585577]), 'ACTION')
# [[-20.72671509 -22.14936256]]
# (0, 'ACTION')
# [[-19.88903618 -21.19779587]]
# (0, 'ACTION')
# [[-18.90750122 -20.07744026]]
# (0, 'ACTION')
# [[-17.8842907  -18.89059639]]
# (0, 'ACTION')
# [[-16.90873718 -17.730093  ]]
# (0, 'ACTION')
# [[-16.04533195 -16.67917633]]
# (0, 'ACTION')
# [[-15.46856022 -15.92455578]]
# (0, 'ACTION')
# [[-15.37200069 -15.62207222]]
# (0, 'ACTION')
# [[-15.60318375 -15.656147  ]]
# (0, 'ACTION')
# (array([-1.6514828]), 'ACTION')
# [[-16.65316582 -16.17890358]]
# (1, 'ACTION')
# [[-16.6499157 -16.1852932]]
# (1, 'ACTION')
# [[-16.53269577 -16.11568642]]
# (1, 'ACTION')
# [[-16.36776733 -16.04480362]]
# (1, 'ACTION')
# [[-16.16938782 -15.97296524]]
# (1, 'ACTION')
# [[-15.9868412  -15.94897747]]
# (1, 'ACTION')
# [[-15.87543201 -16.0298996 ]]
# (0, 'ACTION')
# [[-15.86826229 -16.09353065]]
# (0, 'ACTION')
# (array([-1.91912641]), 'ACTION')
# [[-15.87025642 -16.00118446]]
# (0, 'ACTION')
# [[-15.86572647 -16.0934391 ]]
# (0, 'ACTION')
# [[-15.96258354 -16.31041527]]
# (0, 'ACTION')
# [[-16.19833565 -16.69231606]]
# (0, 'ACTION')
# [[-16.56380653 -17.19822121]]
# (0, 'ACTION')
# [[-17.02450371 -17.77432632]]
# (0, 'ACTION')
# [[-17.49825287 -18.36126518]]
# (0, 'ACTION')
# [[-17.94354248 -18.90906525]]
# (0, 'ACTION')
# [[-18.36616707 -19.41039085]]
# (0, 'ACTION')
# [[-18.70874786 -19.81227875]]
# (0, 'ACTION')
# [[-18.93598175 -20.07904053]]
# (0, 'ACTION')
# [[-19.0422821  -20.20391846]]
# (0, 'ACTION')
# [[-19.01744843 -20.17660904]]
# (0, 'ACTION')
# [[-18.86090851 -19.99611664]]
# (0, 'ACTION')
# [[-18.58100891 -19.67184639]]
# (0, 'ACTION')
# [[-18.21076393 -19.23817444]]
# (0, 'ACTION')
# [[-17.77027702 -18.71245766]]
# (0, 'ACTION')
# [[-17.27647591 -18.11936188]]
# (0, 'ACTION')
# [[-16.77747154 -17.5172081 ]]
# (0, 'ACTION')
# [[-16.29863739 -16.92949486]]
# (0, 'ACTION')
# [[-15.90964508 -16.43521118]]
# (0, 'ACTION')
# (array([ 1.33047938]), 'ACTION')
# [[-15.81783199 -16.30299377]]
# (0, 'ACTION')
# [[-15.6837368  -16.06424713]]
# (0, 'ACTION')
# [[-15.67675114 -15.94720364]]
# (0, 'ACTION')
# [[-15.73888683 -15.91475582]]
# (0, 'ACTION')
# [[-15.83007336 -15.93088818]]
# (0, 'ACTION')
# [[-15.90529728 -15.94679642]]
# (0, 'ACTION')
# [[-15.95833302 -15.95829487]]
# (1, 'ACTION')
# [[-15.87689781 -15.99149418]]
# (0, 'ACTION')
# [[-15.88820171 -16.00076485]]
# (0, 'ACTION')
# [[-15.88732624 -16.01377869]]
# (0, 'ACTION')
# [[-15.8758707  -16.03173637]]
# (0, 'ACTION')
# Episode finished after 200 timesteps
# [[-23.99887657 -16.00118446]]
# [[-40.42020798 -37.39163589]]
# [[-29.96883202 -29.98555756]]
# [[-30.17937279 -21.89871407]]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-7855b4d2d0fb> in <module>()
#      27             break
#      28     if len(memory) >= batch_size:
# ---> 29         update(memory)
#
# <ipython-input-2-176e6d406b87> in update(memory)
#      41         target_f = model.predict(s)
#      42 #         print(a)
# ---> 43         target_f[0][a] = target
#      44         print(target_f)
#      45 #         print(target,s)
#
# IndexError: arrays used as indices must be of integer (or boolean) type
